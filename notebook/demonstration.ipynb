# %%
# Import standard library packages
import os
import xtrack as xt
import matplotlib.pyplot as plt

# Add root directory to python path
os.sys.path.append(os.path.dirname(os.path.abspath('.')))

# Import local package
from src.collider_check import ColliderCheck

# %%
path_collider = "../test_data/collider.json"
collider = xt.Multiline.from_json(path_collider)
collider.build_trackers()
# Out:
# Done loading line from dict.
# Done loading line from dict.
# Done loading line from dict.
# Done loading line from dict.
# Compiling ContextCpu kernels...
# e6a26a5e9ffd490f845c5a3a66b9b58c.c:5035: warning: "_GNU_SOURCE" redefined
#  5035 | #  define _GNU_SOURCE // enable GNU libc NAN extension if possible
#       |
# In file included from e6a26a5e9ffd490f845c5a3a66b9b58c.c:50:
# /home/cdroin/miniconda3/include/python3.10/pyconfig.h:1621: note: this is the location of the previous definition
#  1621 | #define _GNU_SOURCE 1
#       |
# e6a26a5e9ffd490f845c5a3a66b9b58c.c: In function ‘compt_do’:
# e6a26a5e9ffd490f845c5a3a66b9b58c.c:18160:12: warning: unused variable ‘e_loss_primary_tot’ [-Wunused-variable]
# 18160 |     double e_loss_primary_tot = 0.0;  // [GeV] total energy lost by the macroparticle
#       |            ^~~~~~~~~~~~~~~~~~
# e6a26a5e9ffd490f845c5a3a66b9b58c.c:18157:62: warning: variable ‘ps_e_prime’ set but not used [-Wunused-but-set-variable]
# 18157 |     double e_e_prime, px_e_prime, py_e_prime, pzeta_e_prime, ps_e_prime, pt_e_prime;  // [GeV, 1, 1, 1, 1, 1] scattered primary
#       |                                                              ^~~~~~~~~~
# e6a26a5e9ffd490f845c5a3a66b9b58c.c: In function ‘synchrobeam_kick’:
# e6a26a5e9ffd490f845c5a3a66b9b58c.c:18408:21: warning: variable ‘lumi_table_index’ set but not used [-Wunused-but-set-variable]
# 18408 |         RecordIndex lumi_table_index               = NULL;
#       |                     ^~~~~~~~~~~~~~~~
# e6a26a5e9ffd490f845c5a3a66b9b58c.c:18319:18: warning: unused variable ‘pzeta_slice_star’ [-Wunused-variable]
# 18319 |     const double pzeta_slice_star = BeamBeamBiGaussian3DData_get_slices_other_beam_pzeta_center_star(el, i_slice);
#       |                  ^~~~~~~~~~~~~~~~
# Done compiling ContextCpu kernels.
# Compiling ContextCpu kernels...
# 0052a96b6b8847a793232f8ec19dddf3.c:5035: warning: "_GNU_SOURCE" redefined
#  5035 | #  define _GNU_SOURCE // enable GNU libc NAN extension if possible
#       |
# In file included from 0052a96b6b8847a793232f8ec19dddf3.c:50:
# /home/cdroin/miniconda3/include/python3.10/pyconfig.h:1621: note: this is the location of the previous definition
#  1621 | #define _GNU_SOURCE 1
#       |
# 0052a96b6b8847a793232f8ec19dddf3.c: In function ‘compt_do’:
# 0052a96b6b8847a793232f8ec19dddf3.c:18160:12: warning: unused variable ‘e_loss_primary_tot’ [-Wunused-variable]
# 18160 |     double e_loss_primary_tot = 0.0;  // [GeV] total energy lost by the macroparticle
#       |            ^~~~~~~~~~~~~~~~~~
# 0052a96b6b8847a793232f8ec19dddf3.c:18157:62: warning: variable ‘ps_e_prime’ set but not used [-Wunused-but-set-variable]
# 18157 |     double e_e_prime, px_e_prime, py_e_prime, pzeta_e_prime, ps_e_prime, pt_e_prime;  // [GeV, 1, 1, 1, 1, 1] scattered primary
#       |                                                              ^~~~~~~~~~
# 0052a96b6b8847a793232f8ec19dddf3.c: In function ‘synchrobeam_kick’:
# 0052a96b6b8847a793232f8ec19dddf3.c:18408:21: warning: variable ‘lumi_table_index’ set but not used [-Wunused-but-set-variable]
# 18408 |         RecordIndex lumi_table_index               = NULL;
#       |                     ^~~~~~~~~~~~~~~~
# 0052a96b6b8847a793232f8ec19dddf3.c:18319:18: warning: unused variable ‘pzeta_slice_star’ [-Wunused-variable]
# 18319 |     const double pzeta_slice_star = BeamBeamBiGaussian3DData_get_slices_other_beam_pzeta_center_star(el, i_slice);
#       |                  ^~~~~~~~~~~~~~~~
# Done compiling ContextCpu kernels.
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.

# %%
collider_check = ColliderCheck(collider=collider)

# %%
print(collider_check.output_check_as_str())
# Out:
# Tune and chromaticity
# Qx_b1 = 62.3012, Qy_b1 = 60.3098, dQx_b1 = 15.5137, dQy_b1 = 15.3200
# Qx_b2 = 62.3007, Qy_b2 = 60.3099, dQx_b2 = 15.7808, dQy_b2 = 14.7408
#
#
# Linear coupling
# C- b1 = 0.0020, C- b2 = 0.0023
# Momentum compaction factor
# alpha_p b1 = 0.0003, alpha_p b2 = 0.0003
#
#
# Twiss observables
# IP1 (beam 1)
# name          s            x           px             y      py     betx     bety        dx       dy
#  ip1 19994.1624 1.063452e-08 8.858647e-09 -2.473855e-09 0.00016 0.280174 0.295223 -0.000003 0.003532
# IP1 (beam 2)
# name         s            x            px            y      py     betx     bety       dx       dy
#  ip1 6664.7208 6.137003e-09 -3.049983e-08 2.231931e-09 0.00016 0.306458 0.283992 0.000157 0.009701
#
# IP2 (beam 1)
# name            s        x           px             y       py     betx     bety       dx        dy
#  ip2 23326.598984 0.000138 2.943769e-07 -8.479997e-08 0.000272 10.49593 9.889087 0.000758 -0.049358
# IP2 (beam 2)
# name           s        x            px             y       py     betx      bety       dx        dy
#  ip2 3332.436584 0.000138 -3.051886e-07 -4.252373e-08 0.000272 9.829689 10.264667 0.000431 -0.008545
#
# IP5 (beam 1)
# name           s             x      px             y            py     betx     bety        dx        dy
#  ip5 6664.568433 -5.508422e-09 0.00016 -3.943397e-09 -5.662300e-08 0.286131 0.310255 -0.000133 -0.008669
# IP5 (beam 2)
# name            s            x       px            y            py     betx     bety       dx        dy
#  ip5 19994.010033 5.334842e-09 -0.00016 5.918034e-09 -5.746143e-08 0.290267 0.306283 0.000132 -0.001021
#
# IP8 (beam 1)
# name            s         x       px        y       py     betx     bety       dx       dy
#  ip8 16650.658184 -0.000013 0.000139 0.000009 0.000202 1.850617 2.065734 0.000225 0.004609
# IP8 (beam 2)
# name            s         x        px         y       py     betx     bety       dx       dy
#  ip8 10008.377384 -0.000013 -0.000139 -0.000009 0.000202 1.963964 1.860274 0.000047 -0.00372
#
#
#
# Luminosity
# IP1 = 2.0304e+34, IP2 = 1.5250e+30, IP5 = 1.9836e+34, IP8 = 2.0205e+33

# %%
collider_check.plot_orbits(ip="ip1")

# %%
collider_check.plot_separation(ip="ip2")
